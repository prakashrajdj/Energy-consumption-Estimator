# %% [markdown]
# 1.IMPORTING LIBRARIES

# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error,root_mean_squared_error,mean_absolute_percentage_error

import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Users\praka\Downloads\smart_home_energy.csv")
data
# Out:
#       house_size  num_residents  ac_hours_per_day  heating_hours_per_day  \
# 0    1649.014246              4          9.723612               2.526028
# 1    1458.520710              1          3.846620               2.603022
# 2    1694.306561              3          5.300776               4.225101
# 3    1956.908957              5          6.523326               4.890072
# 4    1429.753988              3          8.294819               0.000000
# ..           ...            ...               ...                    ...
# 995  1415.669912              1          2.945560               1.283577
# 996  2039.305958              4          3.164752               1.206132
# 997  1692.252858              6          7.199719               4.677397
# 998  1328.646303              5          5.707826               6.409349
# 999  1671.774834              1          4.814147               2.751803
#
#      appliances_count  avg_outdoor_temp  has_solar  monthly_energy_kwh
# 0                  24         18.666998          0         1131.882644
# 1                  10         21.495016          0          655.942780
# 2                  13         25.166391          0          904.334394
# 3                  17         24.108406          0          992.174641
# 4                  12         32.272766          0          664.622685
# ..                ...               ...        ...                 ...
# 995                13         24.940083          1          636.303069
# 996                21         30.323447          0          972.075662
# 997                 9          6.359610          0          844.557782
# 998                24         19.048484          0          861.559009
# 999                12         23.710470          0          806.262969
#
# [1000 rows x 8 columns]

# %%
#data = data.drop('heating_hours_per_day', axis=1)
#data

# %%
data.head(10)
# Out:
#     house_size  num_residents  ac_hours_per_day  heating_hours_per_day  \
# 0  1649.014246              4          9.723612               2.526028
# 1  1458.520710              1          3.846620               2.603022
# 2  1694.306561              3          5.300776               4.225101
# 3  1956.908957              5          6.523326               4.890072
# 4  1429.753988              3          8.294819               0.000000
# 5  1429.758913              3          5.391552               6.825668
# 6  1973.763845              6          8.397283               6.683402
# 7  1730.230419              1          2.125275               0.000000
# 8  1359.157684              6          3.493304               6.171853
# 9  1662.768013              1          6.697289               6.110438
#
#    appliances_count  avg_outdoor_temp  has_solar  monthly_energy_kwh
# 0                24         18.666998          0         1131.882644
# 1                10         21.495016          0          655.942780
# 2                13         25.166391          0          904.334394
# 3                17         24.108406          0          992.174641
# 4                12         32.272766          0          664.622685
# 5                20          2.588863          1          931.509489
# 6                17          2.904561          0         1208.762621
# 7                17         18.032975          0          683.402752
# 8                21         30.778402          0          853.070168
# 9                24          9.474816          1         1022.366402

# %%
data.head(10)
# Out:
#     house_size  num_residents  ac_hours_per_day  heating_hours_per_day  \
# 0  1649.014246              4          9.723612               2.526028
# 1  1458.520710              1          3.846620               2.603022
# 2  1694.306561              3          5.300776               4.225101
# 3  1956.908957              5          6.523326               4.890072
# 4  1429.753988              3          8.294819               0.000000
# 5  1429.758913              3          5.391552               6.825668
# 6  1973.763845              6          8.397283               6.683402
# 7  1730.230419              1          2.125275               0.000000
# 8  1359.157684              6          3.493304               6.171853
# 9  1662.768013              1          6.697289               6.110438
#
#    appliances_count  avg_outdoor_temp  has_solar  monthly_energy_kwh
# 0                24         18.666998          0         1131.882644
# 1                10         21.495016          0          655.942780
# 2                13         25.166391          0          904.334394
# 3                17         24.108406          0          992.174641
# 4                12         32.272766          0          664.622685
# 5                20          2.588863          1          931.509489
# 6                17          2.904561          0         1208.762621
# 7                17         18.032975          0          683.402752
# 8                21         30.778402          0          853.070168
# 9                24          9.474816          1         1022.366402

# %%
data.tail(10)
# Out:
#       house_size  num_residents  ac_hours_per_day  heating_hours_per_day  \
# 990  1562.514842              1          5.437961               6.285400
# 991   887.479539              3          6.849932               0.534912
# 992  1425.846785              4          4.440687               1.639433
# 993  1295.404726              3          5.424214               4.527093
# 994  1199.513997              3          6.211499               9.139814
# 995  1415.669912              1          2.945560               1.283577
# 996  2039.305958              4          3.164752               1.206132
# 997  1692.252858              6          7.199719               4.677397
# 998  1328.646303              5          5.707826               6.409349
# 999  1671.774834              1          4.814147               2.751803
#
#      appliances_count  avg_outdoor_temp  has_solar  monthly_energy_kwh
# 990                 5         21.000905          0          828.009026
# 991                21         22.125582          0          695.016667
# 992                11         23.749274          0          737.771006
# 993                18         18.429436          1          777.701921
# 994                21         20.394886          1          899.803176
# 995                13         24.940083          1          636.303069
# 996                21         30.323447          0          972.075662
# 997                 9          6.359610          0          844.557782
# 998                24         19.048484          0          861.559009
# 999                12         23.710470          0          806.262969

# %%
data.isna().sum()
# Out:
# house_size               0
# num_residents            0
# ac_hours_per_day         0
# heating_hours_per_day    0
# appliances_count         0
# avg_outdoor_temp         0
# has_solar                0
# monthly_energy_kwh       0
# dtype: int64

# %%
data.dtypes
# Out:
# house_size               float64
# num_residents              int64
# ac_hours_per_day         float64
# heating_hours_per_day    float64
# appliances_count           int64
# avg_outdoor_temp         float64
# has_solar                  int64
# monthly_energy_kwh       float64
# dtype: object

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   house_size             1000 non-null   float64
#  1   num_residents          1000 non-null   int64
#  2   ac_hours_per_day       1000 non-null   float64
#  3   heating_hours_per_day  1000 non-null   float64
#  4   appliances_count       1000 non-null   int64
#  5   avg_outdoor_temp       1000 non-null   float64
#  6   has_solar              1000 non-null   int64
#  7   monthly_energy_kwh     1000 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 62.6 KB

# %% [markdown]
# 2.ASSUMPTIONS

# %%
data.describe()
# Out:
#         house_size  num_residents  ac_hours_per_day  heating_hours_per_day  \
# count  1000.000000    1000.000000       1000.000000            1000.000000
# mean   1505.871997       3.556000          5.936422               4.005662
# std     293.532353       1.699339          1.968683               1.954248
# min     600.000000       1.000000          0.000000               0.000000
# 25%    1305.722908       2.000000          4.590374               2.627311
# 50%    1507.590184       4.000000          6.006887               3.948511
# 75%    1694.383163       5.000000          7.288087               5.366982
# max    2655.819447       6.000000         11.461734              10.123894
#
#        appliances_count  avg_outdoor_temp    has_solar  monthly_energy_kwh
# count       1000.000000       1000.000000  1000.000000         1000.000000
# mean          14.659000         21.681338     0.275000          811.673338
# std            5.793296          7.952903     0.446738          139.693437
# min            5.000000         -3.413631     0.000000          380.563058
# 25%           10.000000         16.525636     0.000000          717.895163
# 50%           15.000000         22.011779     0.000000          810.096994
# 75%           20.000000         27.180649     1.000000          904.080191
# max           24.000000         45.000000     1.000000         1260.668027

# %% [markdown]
# 2.1.Linearity Check

# %%
data.columns
# Out:
# Index(['house_size', 'num_residents', 'ac_hours_per_day',
#        'heating_hours_per_day', 'appliances_count', 'avg_outdoor_temp',
#        'has_solar', 'monthly_energy_kwh'],
#       dtype='object')

# %%
cols=['house_size', 'num_residents', 'ac_hours_per_day','heating_hours_per_day','appliances_count', 'avg_outdoor_temp',
       'has_solar']

# %%
features = ['house_size', 'num_residents', 'ac_hours_per_day','heating_hours_per_day', 'appliances_count', 'avg_outdoor_temp',
       'has_solar']
target = 'monthly_energy_kwh'
for col in features:
    sns.lmplot(x=col, y=target, data=data, line_kws={'color': 'red'})
    plt.title(f"Linearity Check: {col} vs {target}")
    plt.show()

# %%
data.corr()
# Out:
#                        house_size  num_residents  ac_hours_per_day  \
# house_size               1.000000       0.005606          0.029220
# num_residents            0.005606       1.000000          0.011397
# ac_hours_per_day         0.029220       0.011397          1.000000
# heating_hours_per_day    0.031955       0.038230          0.023630
# appliances_count        -0.015285       0.042562          0.002432
# avg_outdoor_temp         0.005764      -0.010530         -0.031489
# has_solar               -0.029586      -0.013054         -0.039138
# monthly_energy_kwh       0.648604       0.221404          0.375160
#
#                        heating_hours_per_day  appliances_count  \
# house_size                          0.031955         -0.015285
# num_residents                       0.038230          0.042562
# ac_hours_per_day                    0.023630          0.002432
# heating_hours_per_day               1.000000          0.037630
# appliances_count                    0.037630          1.000000
# avg_outdoor_temp                   -0.004430          0.000535
# has_solar                          -0.034193          0.006101
# monthly_energy_kwh                  0.321254          0.417577
#
#                        avg_outdoor_temp  has_solar  monthly_energy_kwh
# house_size                     0.005764  -0.029586            0.648604
# num_residents                 -0.010530  -0.013054            0.221404
# ac_hours_per_day              -0.031489  -0.039138            0.375160
# heating_hours_per_day         -0.004430  -0.034193            0.321254
# appliances_count               0.000535   0.006101            0.417577
# avg_outdoor_temp               1.000000   0.000034           -0.168710
# has_solar                      0.000034   1.000000           -0.051912
# monthly_energy_kwh            -0.168710  -0.051912            1.000000

# %%
for col in features:
    plt.figure(figsize=(5, 4))
    sns.distplot(data[col],hist=False)
    plt.title(f"Normality Check: {col}")
    plt.show()

# %% [markdown]
# 3.MODEL BUILDING

# %%
x = data[['house_size', 'num_residents', 'ac_hours_per_day','heating_hours_per_day', 'appliances_count', 'avg_outdoor_temp',
       'has_solar']]
y = data['monthly_energy_kwh']

# %%
x
# Out:
#       house_size  num_residents  ac_hours_per_day  heating_hours_per_day  \
# 0    1649.014246              4          9.723612               2.526028
# 1    1458.520710              1          3.846620               2.603022
# 2    1694.306561              3          5.300776               4.225101
# 3    1956.908957              5          6.523326               4.890072
# 4    1429.753988              3          8.294819               0.000000
# ..           ...            ...               ...                    ...
# 995  1415.669912              1          2.945560               1.283577
# 996  2039.305958              4          3.164752               1.206132
# 997  1692.252858              6          7.199719               4.677397
# 998  1328.646303              5          5.707826               6.409349
# 999  1671.774834              1          4.814147               2.751803
#
#      appliances_count  avg_outdoor_temp  has_solar
# 0                  24         18.666998          0
# 1                  10         21.495016          0
# 2                  13         25.166391          0
# 3                  17         24.108406          0
# 4                  12         32.272766          0
# ..                ...               ...        ...
# 995                13         24.940083          1
# 996                21         30.323447          0
# 997                 9          6.359610          0
# 998                24         19.048484          0
# 999                12         23.710470          0
#
# [1000 rows x 7 columns]

# %%
y
# Out:
# 0      1131.882644
# 1       655.942780
# 2       904.334394
# 3       992.174641
# 4       664.622685
#           ...
# 995     636.303069
# 996     972.075662
# 997     844.557782
# 998     861.559009
# 999     806.262969
# Name: monthly_energy_kwh, Length: 1000, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=35)

# %%
mlr = LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = mlr.predict(x_train)

# %%
y_test_pred = mlr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,mean_absolute_percentage_error,root_mean_squared_error

# %%
mlr_r2 = r2_score(y_test,y_test_pred)
mlr_r2
# Out:
# 0.8600272164441553

# %%
mlr_r2_train = r2_score(y_train,y_train_pred)
mlr_r2_train
# Out:
# 0.8672400062551572

# %%
error_test = y_test - y_test_pred
error_test
# Out:
# 832    -66.534876
# 617     91.530271
# 638   -116.023749
# 939    -29.104479
# 826    -12.031384
#           ...
# 456     25.103679
# 669    -24.033226
# 677     20.230342
# 333     36.572778
# 504    -16.841315
# Name: monthly_energy_kwh, Length: 200, dtype: float64

# %% [markdown]
# Homoscedsicity check:

# %%
for col in features:
    plt.figure(figsize=(5,4))
    plt.scatter(x = x_test[col], y = error_test)
    plt.title(f'Homoscedasticity Check - {col} vs Residuals')
    plt.xlabel(col)
    plt.ylabel('Residuals')
    plt.axhline(0, color='red', linestyle='--')
    plt.show()

# %% [markdown]
# RESIDUALS NORMALITY CHECK

# %%
res = error_test.to_numpy()
res = res[np.isfinite(res)]

# Distplot for normality check
plt.figure(figsize=(6,4))
sns.distplot(res,hist=False)
plt.title("Normality Check - Residuals (Distplot)")
plt.xlabel("Residuals")
plt.ylabel("Density")
plt.show()

# %%
mlr.predict([[1458.520710,1,3.846620,2.603022,10,21.495016,0]])
# Out:
# array([637.47071917])

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("energy prediction.pkl","wb")
pickle.dump(mlr, pickle_out)
pickle_out.close()

# %%
# !pip install streamlit
# Out:
# Access is denied.
